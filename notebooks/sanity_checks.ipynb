# %% [markdown]
# # Sanity checks for standardized transfers
# - 컬럼 존재 여부
# - null 비율
# - 샘플 5건 보기

# %%
import pandas as pd
path='out/std/sample.parquet'
df=pd.read_parquet(path) if path.endswith('.parquet') else pd.read_csv(path)
df.head()
