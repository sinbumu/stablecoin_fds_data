# %% [markdown]
# # Event replay (USDC depeg, USDT 3pool)
# - 일별 집계 로드
# - 기간 필터 후 라인차트

# %%
import pandas as pd
path='out/agg/daily_flows.parquet'
df=pd.read_parquet(path) if path.endswith('.parquet') else pd.read_csv(path)
df.head()
